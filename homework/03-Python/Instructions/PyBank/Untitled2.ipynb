# %%
import csv
import os
total_months= 0
total_revenue = 0
prev_revenue = 0
revenue_change = 0
#greatest_increase= []
greatest_increase= ["",0]
#greatest_decrease = []
greatest_decrease = ["", 999999999999]
revenue_changes = []
csvreader = csv.DictReader(open("raw_data/budget_data_2.csv"))
for row in csvreader:    
                total_months= total_months + 1
                total_revenue=total_revenue + int(row["Revenue"])
#                print( revenue_change ))
                revenue_change=int(row["Revenue"]) - prev_revenue
                print("Revenue_CHANGE : " + str(revenue_change))
                print("Revenue : " + str(row["Revenue"]))
                prev_revenue = int(row["Revenue"])
                print("PREV_REVENUE :" + str(prev_revenue))
                print("Revenue_CHANGE : " + str(revenue_change))
                print("GREATEST_INCREASE : " + str(greatest_increase[1]))
                print("Revenue_CHANGE : " + str(revenue_change))
                if (revenue_change > greatest_increase[1]):
                    print("GREATEST_INCREASE : " + str(greatest_increase[1]))
                    print("Revenue_CHANGE : " + str(revenue_change))
                    greatest_increase[1] = revenue_change
                    print("GREATEST_INCREASE AFTER REVENUE CHANGE: " + str(greatest_increase[1]))
                    greatest_increase[0]=row["Date"]
                if (revenue_change < greatest_decrease[1]):
                    print("GREATEST_DECREASE : " + str(greatest_decrease[1]))
                    print("Revenue_CHANGE : " + str(revenue_change))
                    greatest_decrease[1] = revenue_change
                    print("GREATEST_DECREASE AFTER REVENUE CHANGE: " + str(greatest_decrease[1]))
                    
                    greatest_decrease[0]=row["Date"]
revenue_changes.append(int(row["Revenue"]))
print("Financial Analysis")
print("--------------------------")
print("Total Months: " + str(total_months))
print("Totat Revenue: " +"$" + str(total_revenue))
print("Average Change: "+ "$" + str(round(sum(revenue_changes) / len(revenue_changes),2)))
print("Greatest Increase: " + str(greatest_increase[0] + " ($" + str(greatest_increase[1]) + ")"))
print("Greatest Decrease: " + str(greatest_decrease[0] + " ($" + str(greatest_decrease[1]) + ")"))
# Out:
# Revenue_CHANGE : 943690
# Revenue : 943690
# PREV_REVENUE :943690
# Revenue_CHANGE : 943690
# GREATEST_INCREASE : 0
# Revenue_CHANGE : 943690
# GREATEST_INCREASE : 0
# Revenue_CHANGE : 943690
# GREATEST_INCREASE AFTER REVENUE CHANGE: 943690
# GREATEST_DECREASE : 999999999999
# Revenue_CHANGE : 943690
# GREATEST_DECREASE AFTER REVENUE CHANGE: 943690
# Revenue_CHANGE : 118875
# Revenue : 1062565
# PREV_REVENUE :1062565
# Revenue_CHANGE : 118875
# GREATEST_INCREASE : 943690
# Revenue_CHANGE : 118875
# GREATEST_DECREASE : 943690
# Revenue_CHANGE : 118875
# GREATEST_DECREASE AFTER REVENUE CHANGE: 118875
# Revenue_CHANGE : -852486
# Revenue : 210079
# PREV_REVENUE :210079
# Revenue_CHANGE : -852486
# GREATEST_INCREASE : 943690
# Revenue_CHANGE : -852486
# GREATEST_DECREASE : 118875
# Revenue_CHANGE : -852486
# GREATEST_DECREASE AFTER REVENUE CHANGE: -852486
# Revenue_CHANGE : -945365
# Revenue : -735286
# PREV_REVENUE :-735286
# Revenue_CHANGE : -945365
# GREATEST_INCREASE : 943690
# ...

# %%
greatest_increase= ["",0]
print(greatest_increase)
# Out:
# ['', 0]
